# %% [markdown]
# # Calculation general CME distributions for a fast rotation star.
#
# ## the interesting quantity now is the dopplershift in the direction of the observer
#
# The velocity component of the CME in direction of the observer,
# $$ v \cos \beta = v (\cos \theta \cos \theta' + \sin \theta\sin \theta' \cos \phi') $$
# will now be supplemented by a component comming from the rotation of the star itself, namely
# $$\omega (\alpha) R \sin \tau \sin \sin \phi \sin \theta,$$
# where $\omega (\alpha)$ is the angular frequency at lattitude $\alpha$ and $R$ is the radius of the star, which we assume to be constant.
# For a rigid rotator $\omega (\alpha) = \omega$, for the solar case this has been observed to obey some relation of the form $\omega (\alpha) = A + B \sin^2 + C \sin^4$. The assumption that the fast rotator is a perfect sphere can be corrected by taking $R(\alpha)$ insteand where the radius can vary with lattitude.
#
# In order for this correction to be significant, the order of magnitude of $\omega R$ should be on the order of the velocity of a CME $v$. In the solar case, this correction will be neglegtible.
#
# To solve for the distribution in dopplershift $d$ in direction of the observer, we solve following integral
# \begin{equation}
#     \rho_d(d) = \frac{1}{N} \int_{[0,\pi] \times [0,2\pi]}\sin\theta d\theta d\phi  \rho (\alpha(\theta, \phi)) \int \sin\theta' d\theta' \int d\phi' \rho^{CME}(\theta') \delta(d - v ( \sin \theta \sin \theta' \cos \phi' +\cos \theta' \cos \theta) - \omega (\alpha) R \sin \tau \sin \sin \phi \sin \theta ).
# \end{equation}

# %% [markdown]
# # MONTE CARLO

# %% [markdown]
# import dependencies

# %%
import numpy as np
import scipy.special as sc
import matplotlib.pyplot as plt
from scipy.integrate import quad

# %% [markdown]
# Define the 3D distribution as a function of lattitude $\alpha$.
# (obtained in experimental_flare_distribution.ipynb)

# %%
# general distribution of active regions per unit area 
def rice_dist(x, sigma, nu):
    x = np.abs(x)
    return x / sigma**2 * np.exp( - (x**2 + nu **2 ) / (2 * sigma **2)) * sc.iv(0, (x * nu / sigma**2))

sigma_fit, nu_fit = (9.02769086 / 180 * np.pi, 10.48768514 / 180 * np.pi)

def rho(alpha, err=0.001):
    return rice_dist(np.pi / 2 - alpha, sigma_fit, nu_fit) / 2 / np.pi / (np.sin(alpha) + err) / 2 
            # fit of dist when integrated over phi and absolute value so accounting for that

# %%
alpha = np.linspace(0, np.pi, 100)
plt.plot(alpha, rho(alpha))

# %%
f = lambda x: rice_dist(x, sigma_fit, nu_fit)

# %% [markdown]
# Before for flare distribution we had the relation
# $$
# \cos \alpha = \sin \tau \sin \theta \cos \phi +\cos \theta \cos \tau  $$
# and $\mu = \cos \theta$
#
# Now we work with different variables but they are similar as follows $\beta \sim \alpha, \theta \sim \tau, \theta'\sim \theta$ and $ \phi'\sim \phi$ so
# $$
# \cos \beta = \sin \theta \sin \theta' \cos \phi' +\cos \theta' \cos \theta  $$
# For a proper description we refer to the associated paper.
#
#
#
# The distribution for CME angle is assumed to be gaussion around 0 in the angle with the zenit. We here under properly normalize the distribution!

# %%
from scipy.stats import norm
# normalization, later to be determined
N = 1

def rho_CME(theta2, loc=0, scale = 0.2):
    return norm.pdf(theta2, loc, scale) /N

f = lambda theta2 : rho_CME(theta2) * np.sin(theta2) * 2 * np.pi


N = quad(f, 0, np.pi/2)[0]
print(N)
print(quad(f, 0, np.pi/2)[0])

T = np.linspace(0, np.pi, 100)
plt.plot(T, rho_CME(T))
plt.xlabel("$\\theta'$")
plt.ylabel("distribution of CMEs at angle $\\theta'$ with the zenit")
# Out:
# 0.4946944833802725
# 1.0
# Text(0, 0.5, "distribution of CMEs at angle $\\theta'$ with the zenit")

# %% [markdown]
# # Monte Carlo sampler For a RIGID rotator
# the rigid rotator satisfies
# $\omega R = v$.

# %%
import random
import scipy.stats as stats

x = np.linspace(-2,2, 500)


omega = 1
v = 1
R = 1

def sampler(n):
    theta     = np.arccos(1-2* np.random.random(n))
    phi  = 2*np.pi*np.random.rand(n)
    theta2    = np.arccos(1-0.8*np.random.rand(n))
    phi2 = 2*np.pi*np.random.rand(n)

    return [theta, phi, theta2, phi2]


def get_alpha(tau, theta, phi):
    return np.arccos( np.sin( tau ) * np.sin(theta) * np.cos(phi) + np.cos(tau) * np.cos(theta))

def get_cosbeta(theta,phi, theta2, phi2):
    return np.sin(theta) * np.sin(theta2) *np.cos(phi2) + np.cos(theta2)* np.cos(theta)

def get_occurence(theta, phi, theta2, tau):
    alpha = get_alpha(tau, theta, phi)
    return rho(alpha) * rho_CME(theta2) 

def get_rotational_component(tau, theta, phi):
    return omega * R * np.sin(tau) * np.sin(theta) * np.sin(phi)

def build_list(tau, n=1*10**6):
    (theta, phi, theta2, phi2) = sampler(n)
    # beta = get_beta(theta,phi, theta2, phi2)     
    cosbeta = get_cosbeta(theta,phi, theta2, phi2)  
    rot = get_rotational_component(tau, theta, phi)   
    occ = get_occurence(theta, phi, theta2, tau) 
    return v * cosbeta + rot , occ

def show_density(L, W, label=""):
    # n, xs, _ = plt.hist(L, 
    #                 histtype=u'step', density=True)  
    density = stats.gaussian_kde(L, weights=W)
    plt.plot(x, density(x), label=label)
    return density(x)

def mean_density(dens, taus):
    def D(x):
        R = 0
        for i,d in enumerate(dens):
            R += d(x) * np.sin(taus[i])
        N = sum([np.sin(tau) for tau in taus])
        return R/ N
    return D


def run_taus(T):
    dens = []
    for tau in T:
        print(f"calculating tau = {tau}")
        L , W= build_list(tau)
        dens.append(show_density(L, W, label=fr"$\tau=${round(tau/np.pi*180)}°"))

    # plt.plot(x, np.sin(x)/2, "--", color='black', label="mean")

    plt.legend()
    plt.title("Distribution of CMEs")
    plt.xlabel(r"incident velocity in units of [v]")
    plt.ylabel(r"density []")
    plt.xlim(-2,2)
    # plt.xlim(-1,1)
    plt.show()
    return dens




T = np.linspace(0, np.pi/2, 5)
dens = run_taus(T)
# Out:
# calculating tau = 0.0
# calculating tau = 0.39269908169872414
# calculating tau = 0.7853981633974483
# calculating tau = 1.1780972450961724
# calculating tau = 1.5707963267948966

# %%
def speed2beta(v):
    return np.arccos(v / 600 )

def beta2speed(beta):
    return  np.cos(beta) * 600


def plotting_(dens, taus):
    # fig, 
    for i,d in enumerate(dens):
        plt.plot(x, d, label=fr"$\tau=${round(taus[i]/np.pi*180)}°")
    # mean = mean_density(dens, T)
    # plt.plot(x, mean(x), "--", color='black', label="mean")
    # plt.plot(x, np.sin(x)/2, "--", color='black', label="mean")

    plt.legend()
    plt.title("Distribution of CMEs")
    # plt.xticks(np.linspace(0,np.pi/2, 7), range(0,91,15))
    # ax = plt.gca()
    # secax = ax.secondary_xaxis('top', functions=(beta2speed, speed2beta))
    # secax.set_xlabel(r'$\cos \beta \times 600$ km/h ')
    plt.xlabel(r"incident velocity in units of [v]")
    plt.ylabel(r"density []")
    plt.xlim(-2,2)
    plt.show()

plotting_(dens, T)

# %%
def CME_dist():
    T = np.linspace(0, np.pi/2, 5)
    dens = run_taus(T)
    plotting_(dens, T)

# %% [markdown]
# # Polar flares

# %%
from scipy.stats import norm
# normalization, later to be determined

N = 1

def rho(alpha, loc=0, scale = 0.1):
    return (norm.pdf(alpha, loc, scale) + norm.pdf(alpha, loc+np.pi, scale)) /N

N = quad(lambda a :  rho(a), 0, np.pi/2)[0]
print(N)


alpha = np.linspace(0, np.pi, 100)
plt.plot(alpha, rho(alpha))
plt.title(r"assumed flare distribution over sphere as function of $\alpha$")
plt.xlabel(r"$\alpha$")
plt.ylabel('probability density per unit area')
# Out:
# 0.5000000000000001
# Text(0, 0.5, 'probability density per unit area')

# %%
# general distribution in mu for given tau
def get_alpha(tau, theta, phi):
    return np.arccos( np.sin( tau ) * np.sin(theta) * np.cos(phi) + np.cos(tau) * np.cos(theta))

    
def Flare_dist():

    def rho_mu(mu, tau):
        theta = np.arccos(mu)
        I = lambda phi: rho(get_alpha(tau, theta, phi))
        return 2 * quad(I, 0, 2*np.pi)[0]

    def rho_mus(mus, tau):
        return [ rho_mu(mu,tau) for mu in mus]

    rho_mu_of_tau = lambda tau : lambda mu : rho_mu(mu, tau)

    # def rho_mus2(mus, tau):
    #     return [ rho_mu(mu,tau) * (1-mu**2)**0.5 for mu in mus]

    mu = np.linspace(0,1, 100)

    for tau in np.linspace(0,np.pi/2, 5):
        plt.plot(mu, rho_mus(mu, tau), label=fr'$\tau=${round(tau*180/np.pi)}°')
        print(tau, quad(rho_mu_of_tau(tau), 0, 1))
    
    plt.plot(mu, mu*0+1, "--", color="black", label="mean")

    # plt.ylim(0,5)
    plt.title(r"Distribution of flares in $\mu$")
    plt.xlabel(r"$\mu$")
    plt.ylabel("probabilty density")
    plt.legend()
    plt.show()

# %%
Flare_dist()
CME_dist()
# Out:
# 0.0 (0.9993158136231646, 3.647190528409362e-12)
# 0.39269908169872414 (0.9993158136231631, 1.694194277505706e-13)
# 0.7853981633974483 (0.9993158136231668, 7.908570194260995e-11)
# 1.1780972450961724 (0.9993158136231668, 4.542747928977166e-09)
# 1.5707963267948966 (0.9993158136231646, 1.2719183056504428e-09)
# calculating tau = 0.0
# calculating tau = 0.39269908169872414
# calculating tau = 0.7853981633974483
# calculating tau = 1.1780972450961724
# calculating tau = 1.5707963267948966

# %% [markdown]
# # flares around Equator (normal dist, no dip)

# %%
from scipy.stats import norm

def rho(alpha, loc=np.pi/2, scale = 0.3, err = 0.01):
    return norm.pdf(alpha, loc, scale) / 2 / np.pi / (np.sin(alpha) + err) 

alpha = np.linspace(0, np.pi, 100)
plt.plot(alpha, rho(alpha))
plt.title(r"assumed flare distribution over sphere as function of $\alpha$")
plt.xlabel(r"$\alpha$")
plt.ylabel('probability density per unit area')
# Out:
# Text(0, 0.5, 'probability density per unit area')

# %%
CME_dist()
# Out:
# calculating tau = 0.0
# calculating tau = 0.39269908169872414
# calculating tau = 0.7853981633974483
# calculating tau = 1.1780972450961724
# calculating tau = 1.5707963267948966

# %% [markdown]
# # Flares with stepfunction dist around equator

# %%
def rho(alpha, h=30/180*np.pi):
    return np.where(np.abs(alpha-np.pi/2) < h, 1, 0)


alpha = np.linspace(0, np.pi, 100)
plt.plot(alpha, rho(alpha))
plt.title(r"assumed flare distribution over sphere as function of $\alpha$")
plt.xlabel(r"$\alpha$")
plt.ylabel('probability density per unit area')
# Out:
# Text(0, 0.5, 'probability density per unit area')

# %%
CME_dist()
# Out:
# calculating tau = 0.0
# calculating tau = 0.39269908169872414
# calculating tau = 0.7853981633974483
# calculating tau = 1.1780972450961724
# calculating tau = 1.5707963267948966

# %% [markdown]
# # intergral numerical

# %%
# import time
# # import mcint
# import random
# import math
# from scipy.integrate import nquad

# # epsabs=1e-10, epsrel=1e-10,

# def sampler():
#     while True:
#         theta     = random.uniform(0, np.pi)
#         phi  = random.uniform(0, 2*np.pi)
#         theta2    = random.uniform(0, np.pi/2)
    
#         yield (theta, phi, theta2)

# def get_rho_beta(beta, tau, fast=True):
#     if fast:
#         result, error = mcint.integrate(f_integrand_(beta, tau), sampler(), measure=1, n=10000, epsrel=1e-6)
#         print(error)
#     else:
#         start_time = time.time()
#         print(beta, tau, end='\r')
#         result, error = nquad(f_integrand_(beta, tau, vec=False), [[0, np.pi],       # theta, phi, theta2
#                                                     [0, 2*np.pi],         # phi
#                                                     [0, np.pi / 2 ]], opts={"epsrel":0.1, 'epsabs':1e-1})        # theta2
#         end_time = time.time()
#         print(f'For params {beta=}, {tau = } we find the distibution to be {result}, with estimated error {error}. \
#             Taking {(end_time-start_time):.2f} to calculate.')

#     return result


# def rho_betas(betas, tau, fast=True):
#     return [get_rho_beta(beta, tau, fast) for beta in betas]

# betas = np.linspace(0,np.pi/2, 20)

# for tau in np.linspace(0,np.pi/2, 5):
#     a = rho_betas(betas, tau, fast)
#     plt.plot(betas, a, label=fr'$\tau=${round(tau*180/np.pi)}°')
#     print(betas, a)

# # plt.ylim(0,5)
# plt.title(r"Distribution of CME's in $\beta$")
# plt.xlabel(r"$\beta$")
# plt.ylabel("probabilty density")
# plt.legend()
# Out:
# 0.0 0.0
# C:\Users\mdewilde\AppData\Local\Temp\ipykernel_20928\1033664869.py:28: RuntimeWarning: invalid value encountered in scalar divide
#   return np.sin(theta)**2 * rho(alpha) * np.sin(theta2)**2 * rho_CME(theta2) * sinphi2 / np.abs(np.sin(beta))
# C:\Users\mdewilde\AppData\Local\Temp\ipykernel_20928\1033664869.py:28: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sin(theta)**2 * rho(alpha) * np.sin(theta2)**2 * rho_CME(theta2) * sinphi2 / np.abs(np.sin(beta))
# c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1260: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 40
#      37 betas = np.linspace(0,np.pi/2, 20)
#      39 for tau in np.linspace(0,np.pi/2, 5):
# ---> 40     a = rho_betas(betas, tau, fast)
#      41     plt.plot(betas, a, label=fr'$\tau=${round(tau*180/np.pi)}°')
#      42     print(betas, a)
#
# Cell In[60], line 35, in rho_betas(betas, tau, fast)
#      34 def rho_betas(betas, tau, fast=True):
# ---> 35     return [get_rho_beta(beta, tau, fast) for beta in betas]
#
# Cell In[60], line 24, in get_rho_beta(beta, tau, fast)
#      22 start_time = time.time()
#      23 print(beta, tau, end='\r')
# ---> 24 result, error = nquad(f_integrand_(beta, tau, vec=False), [[0, np.pi],       # theta, phi, theta2
#      25                                             [0, 2*np.pi],         # phi
#      26                                             [0, np.pi / 2 ]], opts={"epsrel":0.1, 'epsabs':1e-1})        # theta2
#      27 end_time = time.time()
#      28 print(f'For params {beta=}, {tau = } we find the distibution to be {result}, with estimated error {error}. \
#      29     Taking {(end_time-start_time):.2f} to calculate.')
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1206, in nquad(func, ranges, args, opts, full_output)
#    1204 else:
#    1205     opts = [opt if callable(opt) else _OptFunc(opt) for opt in opts]
# -> 1206 return _NQuad(func, ranges, opts, full_output).integrate(*args)
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1260, in _NQuad.integrate(self, *args, **kwargs)
#    1258 else:
#    1259     f = partial(self.integrate, depth=depth+1)
# -> 1260 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#    1261               **opt)
#    1262 value = quad_r[0]
#    1263 abserr = quad_r[1]
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:459, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     456     return retval
#     458 if weight is None:
# --> 459     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     460                    points)
#     461 else:
#     462     if points is not None:
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:606, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     604 if points is None:
#     605     if infbounds == 0:
# --> 606         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     607     else:
#     608         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     609                                 epsabs, epsrel, limit)
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1260, in _NQuad.integrate(self, *args, **kwargs)
#    1258 else:
#    1259     f = partial(self.integrate, depth=depth+1)
# -> 1260 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#    1261               **opt)
#    1262 value = quad_r[0]
#    1263 abserr = quad_r[1]
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:459, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     456     return retval
#     458 if weight is None:
# --> 459     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     460                    points)
#     461 else:
#     462     if points is not None:
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:606, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     604 if points is None:
#     605     if infbounds == 0:
# --> 606         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     607     else:
#     608         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     609                                 epsabs, epsrel, limit)
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1260, in _NQuad.integrate(self, *args, **kwargs)
#    1258 else:
#    1259     f = partial(self.integrate, depth=depth+1)
# -> 1260 quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#    1261               **opt)
#    1262 value = quad_r[0]
#    1263 abserr = quad_r[1]
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:459, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst, complex_func)
#     456     return retval
#     458 if weight is None:
# --> 459     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     460                    points)
#     461 else:
#     462     if points is not None:
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:606, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     604 if points is None:
#     605     if infbounds == 0:
# --> 606         return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     607     else:
#     608         return _quadpack._qagie(func, bound, infbounds, args, full_output,
#     609                                 epsabs, epsrel, limit)
#
# Cell In[6], line 21, in f_integrand_.<locals>.integrand2(theta, phi, theta2)
#      20 def integrand2(theta, phi, theta2):
# ---> 21     return integrand(theta, phi, theta2, beta, tau)
#
# Cell In[6], line 28, in integrand(theta, phi, theta2, beta, tau)
#      25 sinphi2 = get_sinphi2(theta, phi, theta2, beta)
#      26 alpha = get_alpha(tau, theta, phi)
# ---> 28 return np.sin(theta)**2 * rho(alpha) * np.sin(theta2)**2 * rho_CME(theta2) * sinphi2 / np.abs(np.sin(beta))
#
# Cell In[5], line 6, in rho_CME(theta2, loc, scale)
#       5 def rho_CME(theta2, loc=0, scale = 0.2):
# ----> 6     return norm.pdf(theta2, loc, scale) /N
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\scipy\stats\_distn_infrastructure.py:2055, in rv_continuous.pdf(self, x, *args, **kwds)
#    2053     goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#    2054     scale, goodargs = goodargs[-1], goodargs[:-1]
# -> 2055     place(output, cond, self._pdf(*goodargs) / scale)
#    2056 if output.ndim == 0:
#    2057     return output[()]
#
# File c:\Users\mdewilde\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:2027, in place(arr, mask, vals)
#    1989 @array_function_dispatch(_place_dispatcher)
#    1990 def place(arr, mask, vals):
#    1991     """
#    1992     Change elements of an array based on conditional and input values.
#    1993
#    (...)
#    2025
#    2026     """
# -> 2027     return _place(arr, mask, vals)
#
# KeyboardInterrupt:

# %%
# partial results after 40 min of fast=False integration

b = np.array([0.         , 0.08267349 , 0.16534698 , 0.24802047, 0.33069396 , 0.41336745, 0.49604095 , 0.57871444 , 0.66138793 , 0.74406142, 0.82673491, 0.9094084, 0.99208189 , 1.07475538 , 1.15742887 , 1.24010236 , 1.32277585 , 1.40544935, 1.48812284 , 1.57079633])
p1=np.array([-1.244302803098822e-07, -2.020597301041954e-08, -2.9419197471627263e-09, -3.8506323427838335e-10, -3.9187265313228005e-11, 1.9396522511149444e-10, 4.663246386506073e-09, 8.342455036253888e-08, 1.1389400438405107e-06, 1.1879469422441976e-05, 9.478730484257619e-05, 0.0005795594748075021, 0.0027215705946284224, 0.009845515893399727, 0.027552861542427205, 0.059989051795611634, 0.10235890555562867, 0.13789471596377173, 0.1466504419075839, 0.11862377157730396])

b2 = [0.08267349088394192, 0.16534698176788384, 0.24802047265182575, 0.3306939635357677, 0.4133674544197096, 0.4960409453036515, 0.5787144361875934, 0.6613879270715354, 0.7440614179554773, 0.8267349088394192, 0.9094083997233612, 0.992081890607303,  1.074755381491245,  1.1574288723751869]
p2 = [ -2.22823150296887e-05, -5.713519770368957e-06, -1.3154789700561033e-06 -2.291901862322346e-07, 5.214006036830509e-07,  5.532554756659216e-06,  4.068847682634011e-05,  0.00022888900934754633,  0.0009946273992843017, 0.0033683418491653166, 0.008984065218520531, 0.019127553436737478,0.033065651186741915, 0.047353504995598206,  0.05729989712276298]


plt.plot(b, p1, label=fr'$\tau=$0°')
plt.plot(b2, p2, label=fr'$\tau=$0.4°$')

# plt.ylim(0,5)
plt.title(r"Distribution of CME's in $\beta$")
plt.xlabel(r"$\beta$")
plt.ylabel("probabilty density")
plt.legend()

# %% [markdown]
# # Calculation of distribution of CMEs in viewing angle $\beta$ for average $\tau$.
# Here we calculate the distribution of CMEs in viewing angle $\beta$ for average $\tau$. This distribution is analytically simplified to the following:

# %% [markdown]
# \begin{equation}
#     \rho^{\text{average }\tau}_\beta(\beta) = \frac{2}{N|\sin\beta|}  \int_{[0,\pi]  \times [0,\pi/2] } d\theta d\theta'  \rho^{CME}(\theta') \sin^2\theta\sin^2\theta'\sin\phi'(\theta, \theta',\beta)
# \end{equation}

# %%
from scipy import integrate
def get_sinphi2(theta, theta2, beta):
    cosphi2 = (np.cos(beta)  - np.cos(theta)*np.cos(theta2) )/ (np.sin(theta)*np.sin(theta2)) 
    return 0 if np.abs(cosphi2) >1 else (1-cosphi2**2)**0.5

def f_integrand_any_tau(beta):
        def integrand2(theta, theta2):
            return integrand_any_tau(theta, theta2, beta)
        return integrand2

def integrand_any_tau(theta, theta2, beta):
    sinphi2 = get_sinphi2(theta, theta2, beta)
        
    return np.sin(theta)**2 * np.sin(theta2)**2 * rho_CME(theta2) * sinphi2 / np.abs(np.sin(beta))


def get_rho_beta_any_tau(beta):
    start_time = time.time()
    print(beta, end='\r')
    result, error = integrate.nquad(f_integrand_any_tau(beta), [[0, np.pi], [0, np.pi / 2 ]], opts={"epsrel":5e-3})      # theta, phi, theta2

    end_time = time.time()
    print(f'For params {beta=}we find the distibution to be {result}, with estimated error {error}. \
        Taking {(end_time-start_time):.2f} to calculate.')

    return result

# %%
def rho_betas(betas):
    return [get_rho_beta_any_tau(beta) for beta in betas]

betas = np.linspace(0.01,np.pi/2, 50)

a = rho_betas(betas)
plt.plot(betas, a, label=r'average $\tau$')
print(betas, a)

# plt.ylim(0,5)
plt.title(r"Distribution of CME's in $\beta$")
plt.xlabel(r"$\beta$")
plt.ylabel("probabilty density")
plt.legend()
# Out:
# For params beta=0.01we find the distibution to be 5.610671795476592e-11, with estimated error 4.443782030348164e-06.         Taking 0.55 to calculate.
# 0.04185298626112034
# c:\Users\Gebruiker\Anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# For params beta=0.04185298626112034we find the distibution to be 0.000422490325536906, with estimated error 2.300188761641085e-05.         Taking 111.26 to calculate.
# For params beta=0.07370597252224068we find the distibution to be 0.0012970576771701217, with estimated error 3.6524692369067045e-05.         Taking 36.43 to calculate.
# For params beta=0.10555895878336101we find the distibution to be 0.001973377052457322, with estimated error 4.9102646036488416e-05.         Taking 3.62 to calculate.
# For params beta=0.13741194504448137we find the distibution to be 0.002566226406715436, with estimated error 5.601600776860454e-05.         Taking 1.11 to calculate.
# For params beta=0.16926493130560172we find the distibution to be 0.003154587262427889, with estimated error 8.054344870841155e-05.         Taking 3.64 to calculate.
# For params beta=0.20111791756672204we find the distibution to be 0.0037412889792924724, with estimated error 9.20631436659507e-05.         Taking 1.30 to calculate.
# For params beta=0.23297090382784238we find the distibution to be 0.004323620575464476, with estimated error 7.982563439207051e-05.         Taking 1.49 to calculate.
# For params beta=0.26482389008896273we find the distibution to be 0.004902112336603346, with estimated error 0.00010304630726746568.         Taking 1.41 to calculate.
# For params beta=0.29667687635008305we find the distibution to be 0.005474227743258202, with estimated error 0.00011342231793563806.         Taking 3.60 to calculate.
# For params beta=0.3285298626112034we find the distibution to be 0.006042270071104566, with estimated error 0.000167716662398148.         Taking 1.54 to calculate.
# For params beta=0.36038284887232375we find the distibution to be 0.006603850511892218, with estimated error 0.00019381992451755065.         Taking 17.99 to calculate.
# For params beta=0.39223583513344407we find the distibution to be 0.007161597550901885, with estimated error 0.00014752479124753034.         Taking 1.32 to calculate.
# For params beta=0.42408882139456444we find the distibution to be 0.0076837331719061645, with estimated error 0.00021667449030415826.         Taking 14.32 to calculate.
# For params beta=0.45594180765568476we find the distibution to be 0.008245340115719441, with estimated error 0.00023707534285071288.         Taking 16.63 to calculate.
# For params beta=0.48779479391680514we find the distibution to be 0.008777875267725475, with estimated error 0.0002278229976455555.         Taking 5.85 to calculate.
# For params beta=0.5196477801779255we find the distibution to be 0.009297876208801048, with estimated error 0.0002509622338847453.         Taking 6.58 to calculate.
# For params beta=0.5515007664390458we find the distibution to be 0.009813323899430813, with estimated error 0.00024502173878099276.         Taking 2.95 to calculate.
# For params beta=0.5833537527001661we find the distibution to be 0.01028483689139823, with estimated error 0.0002960936575182965.         Taking 12.20 to calculate.
# For params beta=0.6152067389612865we find the distibution to be 0.010778524104151426, with estimated error 0.00031872225910658386.         Taking 26.97 to calculate.
# For params beta=0.6470597252224068we find the distibution to be 0.011289503047413085, with estimated error 0.00030340710647992764.         Taking 1.07 to calculate.
# For params beta=0.6789127114835272we find the distibution to be 0.0117589391614836, with estimated error 0.0002278630533349875.         Taking 1.19 to calculate.
# For params beta=0.7107656977446475we find the distibution to be 0.01221565252488812, with estimated error 0.0002703405050790489.         Taking 1.02 to calculate.
# For params beta=0.7426186840057678we find the distibution to be 0.01265497372848251, with estimated error 0.0003648940717262642.         Taking 19.14 to calculate.
# For params beta=0.7744716702668881we find the distibution to be 0.013035420976683436, with estimated error 0.00038529592371052324.         Taking 15.28 to calculate.
# For params beta=0.8063246565280086we find the distibution to be 0.013464784474811408, with estimated error 0.00038137545834028867.         Taking 15.75 to calculate.
# For params beta=0.8381776427891289we find the distibution to be 0.013919864743051031, with estimated error 0.0002206088556567995.         Taking 0.94 to calculate.
# For params beta=0.8700306290502492we find the distibution to be 0.01431403382013245, with estimated error 0.00030965593659900727.         Taking 2.93 to calculate.
# For params beta=0.9018836153113695we find the distibution to be 0.014694653464597222, with estimated error 0.000388577990481212.         Taking 1.04 to calculate.
# For params beta=0.9337366015724898we find the distibution to be 0.015055651713671835, with estimated error 0.0003548946279486943.         Taking 1.02 to calculate.
# For params beta=0.9655895878336103we find the distibution to be 0.01536532282591325, with estimated error 0.00044935707754560216.         Taking 26.55 to calculate.
# For params beta=0.9974425740947306we find the distibution to be 0.015571484814664492, with estimated error 0.00044061957819181144.         Taking 16.28 to calculate.
# For params beta=1.029295560355851we find the distibution to be 0.01600175947237215, with estimated error 0.0004503429449846455.         Taking 22.48 to calculate.
# For params beta=1.0611485466169712we find the distibution to be 0.016348897323814032, with estimated error 0.0004187622986665618.         Taking 1.07 to calculate.
# For params beta=1.0930015328780915we find the distibution to be 0.016628380168457295, with estimated error 0.00046751747582462284.         Taking 25.32 to calculate.
# For params beta=1.1248545191392119we find the distibution to be 0.016895884674840787, with estimated error 0.0003157795114075296.         Taking 1.03 to calculate.
# For params beta=1.1567075054003322we find the distibution to be 0.017145564948877676, with estimated error 0.00043929473133520053.         Taking 2.67 to calculate.
# For params beta=1.1885604916614525we find the distibution to be 0.01732135732676938, with estimated error 0.00047490306475658035.         Taking 15.47 to calculate.
# For params beta=1.220413477922573we find the distibution to be 0.01739275049248761, with estimated error 0.0005030640854405827.         Taking 25.40 to calculate.
# For params beta=1.2522664641836934we find the distibution to be 0.0177106940852171, with estimated error 0.0005102213110073153.         Taking 14.91 to calculate.
# For params beta=1.2841194504448137we find the distibution to be 0.017961552703391444, with estimated error 0.0004138420010913607.         Taking 0.88 to calculate.
# For params beta=1.315972436705934we find the distibution to be 0.01812382682005177, with estimated error 0.0003878528180384644.         Taking 0.94 to calculate.
# For params beta=1.3478254229670543we find the distibution to be 0.018264957899120287, with estimated error 0.0003623229879853099.         Taking 1.00 to calculate.
# For params beta=1.3796784092281746we find the distibution to be 0.01838517557837249, with estimated error 0.0004227805949185508.         Taking 2.89 to calculate.
# For params beta=1.411531395489295we find the distibution to be 0.018450393872819854, with estimated error 0.0005364416492551552.         Taking 20.24 to calculate.
# For params beta=1.4433843817504153we find the distibution to be 0.018406956879752603, with estimated error 0.0005352841022089952.         Taking 29.39 to calculate.
# For params beta=1.4752373680115356we find the distibution to be 0.018523759174190493, with estimated error 0.0004991414071267436.         Taking 11.66 to calculate.
# For params beta=1.507090354272656we find the distibution to be 0.018665304740632587, with estimated error 0.0005512170231993763.         Taking 20.72 to calculate.
# For params beta=1.5389433405337762we find the distibution to be 0.01871795246234674, with estimated error 0.0004842033608375082.         Taking 13.03 to calculate.
# For params beta=1.5707963267948966we find the distibution to be 0.018727931587596766, with estimated error 0.000367666662165542.         Taking 1.68 to calculate.
# [0.01       0.04185299 0.07370597 0.10555896 0.13741195 0.16926493
#  0.20111792 0.2329709  0.26482389 0.29667688 0.32852986 0.36038285
#  0.39223584 0.42408882 0.45594181 0.48779479 0.51964778 0.55150077
#  0.58335375 0.61520674 0.64705973 0.67891271 0.7107657  0.74261868
#  0.77447167 0.80632466 0.83817764 0.87003063 0.90188362 0.9337366
#  0.96558959 0.99744257 1.02929556 1.06114855 1.09300153 1.12485452
#  1.15670751 1.18856049 1.22041348 1.25226646 1.28411945 1.31597244
#  1.34782542 1.37967841 1.4115314  1.44338438 1.47523737 1.50709035
#  1.53894334 1.57079633] [5.610671795476592e-11, 0.000422490325536906, 0.0012970576771701217, 0.001973377052457322, 0.002566226406715436, 0.003154587262427889, 0.0037412889792924724, 0.004323620575464476, 0.004902112336603346, 0.005474227743258202, 0.006042270071104566, 0.006603850511892218, 0.007161597550901885, 0.0076837331719061645, 0.008245340115719441, 0.008777875267725475, 0.009297876208801048, 0.009813323899430813, 0.01028483689139823, 0.010778524104151426, 0.011289503047413085, 0.0117589391614836, 0.01221565252488812, 0.01265497372848251, 0.013035420976683436, 0.013464784474811408, 0.013919864743051031, 0.01431403382013245, 0.014694653464597222, 0.015055651713671835, 0.01536532282591325, 0.015571484814664492, 0.01600175947237215, 0.016348897323814032, 0.016628380168457295, 0.016895884674840787, 0.017145564948877676, 0.01732135732676938, 0.01739275049248761, 0.0177106940852171, 0.017961552703391444, 0.01812382682005177, 0.018264957899120287, 0.01838517557837249, 0.018450393872819854, 0.018406956879752603, 0.018523759174190493, 0.018665304740632587, 0.01871795246234674, 0.018727931587596766]

# %% [markdown]
# for $\kappa = \cos \beta$ we have $d\kappa =  - \sin \beta d\beta$ and therefore as $\rho_\beta(\beta)d\beta = -\rho_\kappa d\kappa$ so $\rho_\kappa(\kappa) = \sin \beta \rho_\beta(\beta)$.
# \begin{equation}
#     \rho^{\text{any }\tau}_\kappa(\kappa) = \frac{2}{N|}  \int_{[0,\pi]  \times [0,\pi/2] } d\theta d\theta'  \rho^{CME}(\theta') \sin^2\theta\sin^2\theta'\sin\phi'(\theta, \theta',\beta)
# \end{equation}

# %%
from scipy import integrate
def get_sinphi2(theta, theta2, beta):
    cosphi2 = (np.cos(beta)  - np.cos(theta)*np.cos(theta2) )/ (np.sin(theta)*np.sin(theta2)) 
    return 0 if np.abs(cosphi2) >1 else (1-cosphi2**2)**0.5

def _integrand_any_tau(beta):
        def integrand2(theta, theta2):
            return integrandk_any_tau(theta, theta2, beta)
        return integrand2

def integrandk_any_tau(theta, theta2, beta):
    sinphi2 = get_sinphi2(theta, theta2, beta)
        
    return np.sin(theta)**2 * np.sin(theta2)**2 * rho_CME(theta2) * sinphi2 


def get_rho_kappa_any_tau(kappa):
    start_time = time.time()
    beta = np.acos(kappa)
    print(beta, end='\r')
    result, error = integrate.nquad(_integrand_any_tau(beta), [[0, np.pi], [0, np.pi / 2 ]], opts={"epsrel":1e-2})      # theta, phi, theta2

    end_time = time.time()
    print(f'For params {beta=} we find the distibution to be {result}, with estimated error {error}. \
        Taking {(end_time-start_time):.2f} to calculate.')

    return result


def rho_kappas(kappas):
    return [get_rho_beta_any_tau(kappa) for kappa in kappas]

kappas = np.linspace(0,np.pi/2, 10)

a = rho_betas(kappas)
plt.plot(kappas, a, label=r'average $\tau$')
print(kappas, a)

# plt.ylim(0,5)
plt.title(r"Distribution of CME's in $\kappa$")
plt.xlabel(r"$\kappa$")
plt.ylabel("probabilty density")
plt.legend()
plt.legend()
# Out:
# 0.0
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_17180\2099028693.py:14: RuntimeWarning: invalid value encountered in scalar divide
#   return np.sin(theta)**2 * np.sin(theta2)**2 * rho_CME(theta2) * sinphi2 / np.abs(np.sin(beta))
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_17180\2099028693.py:14: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sin(theta)**2 * np.sin(theta2)**2 * rho_CME(theta2) * sinphi2 / np.abs(np.sin(beta))
# c:\Users\Gebruiker\Anaconda3\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# For params beta=0.0we find the distibution to be nan, with estimated error 0.         Taking 40.60 to calculate.
# For params beta=0.17453292519943295we find the distibution to be 0.00325053778444515, with estimated error 7.215804674636731e-05.         Taking 1.05 to calculate.
# For params beta=0.3490658503988659we find the distibution to be 0.006404679842274804, with estimated error 0.00016190302629126227.         Taking 3.35 to calculate.
# For params beta=0.5235987755982988we find the distibution to be 0.00936446440427478, with estimated error 0.00019663618008163573.         Taking 1.02 to calculate.
# For params beta=0.6981317007977318we find the distibution to be 0.012038668682387338, with estimated error 0.00025129613738313875.         Taking 3.95 to calculate.
# For params beta=0.8726646259971648we find the distibution to be 0.014346896023031658, with estimated error 0.0003962472974852818.         Taking 5.43 to calculate.
# For params beta=1.0471975511965976we find the distibution to be 0.0162038548356757, with estimated error 0.00043344925478029303.         Taking 12.18 to calculate.
# For params beta=1.2217304763960306we find the distibution to be 0.017380107311610982, with estimated error 0.0005115127603115346.         Taking 11.53 to calculate.
# For params beta=1.3962634015954636we find the distibution to be 0.018428364620120822, with estimated error 0.0005412310351154443.         Taking 19.50 to calculate.
# For params beta=1.5707963267948966we find the distibution to be 0.018727931587596766, with estimated error 0.000367666662165542.         Taking 1.28 to calculate.
# [0.         0.17453293 0.34906585 0.52359878 0.6981317  0.87266463
#  1.04719755 1.22173048 1.3962634  1.57079633] [nan, 0.00325053778444515, 0.006404679842274804, 0.00936446440427478, 0.012038668682387338, 0.014346896023031658, 0.0162038548356757, 0.017380107311610982, 0.018428364620120822, 0.018727931587596766]

# %%
kappas = np.linspace(0,np.pi/2, 10)

plt.plot(kappas, a, label=r'average $\tau$')
print(kappas, a)

# plt.ylim(0,5)
plt.title(r"Distribution of CME's in $\kappa$ for general $\tau$")
plt.xlabel(r"$\kappa$")
plt.ylabel("probabilty density")
plt.legend()
plt.legend()
# Out:
# [0.         0.17453293 0.34906585 0.52359878 0.6981317  0.87266463
#  1.04719755 1.22173048 1.3962634  1.57079633] [nan, 0.00325053778444515, 0.006404679842274804, 0.00936446440427478, 0.012038668682387338, 0.014346896023031658, 0.0162038548356757, 0.017380107311610982, 0.018428364620120822, 0.018727931587596766]
